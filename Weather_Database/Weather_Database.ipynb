# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 616

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cb7e913b60509fb0b1fc7097ce6c2652

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
   # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tiznit
# Processing Record 2 of Set 1 | bansda
# City not found. Skipping...
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | krasnorechenskiy
# Processing Record 7 of Set 1 | cabo san lucas
# Processing Record 8 of Set 1 | kahului
# Processing Record 9 of Set 1 | long xuyen
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | tuatapere
# Processing Record 12 of Set 1 | ust-koksa
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | pombas
# Processing Record 15 of Set 1 | virginia beach
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | igarka
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | meulaboh
# Processing Record 21 of Set 1 | upernavik
# Processing Record 22 of Set 1 | lebu
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | airai
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | bahia blanca
# Processing Record 27 of Set 1 | saint-philippe
# Processing Record 28 of Set 1 | goundam
# Processing Record 29 of Set 1 | carnarvon
# Processing Record 30 of Set 1 | sao filipe
# Processing Record 31 of Set 1 | nikolskoye
# Processing Record 32 of Set 1 | isilkul
# Processing Record 33 of Set 1 | olafsvik
# Processing Record 34 of Set 1 | arys
# Processing Record 35 of Set 1 | constitucion
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | pisco
# Processing Record 38 of Set 1 | camacha
# Processing Record 39 of Set 1 | khatanga
# Processing Record 40 of Set 1 | laramie
# Processing Record 41 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 1 | dikson
# Processing Record 43 of Set 1 | ponta delgada
# Processing Record 44 of Set 1 | kasane
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | longyearbyen
# Processing Record 48 of Set 1 | batemans bay
# Processing Record 49 of Set 1 | provideniya
# Processing Record 50 of Set 1 | weligama
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | pangai
# Processing Record 3 of Set 2 | saint george
# Processing Record 4 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 2 | muros
# Processing Record 6 of Set 2 | acapulco
# Processing Record 7 of Set 2 | mount gambier
# Processing Record 8 of Set 2 | barrow
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | sao lourenco do sul
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | lagoa
# Processing Record 13 of Set 2 | ilulissat
# Processing Record 14 of Set 2 | richards bay
# Processing Record 15 of Set 2 | punta arenas
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | bethel
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 2 | inzer
# Processing Record 22 of Set 2 | hamilton
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | lamu
# Processing Record 25 of Set 2 | talnakh
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | kieta
# Processing Record 28 of Set 2 | castro
# Processing Record 29 of Set 2 | erzin
# Processing Record 30 of Set 2 | omboue
# Processing Record 31 of Set 2 | broome
# Processing Record 32 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 2 | lavrentiya
# Processing Record 34 of Set 2 | kapaa
# Processing Record 35 of Set 2 | kavieng
# Processing Record 36 of Set 2 | san francisco del mar
# Processing Record 37 of Set 2 | general roca
# Processing Record 38 of Set 2 | comodoro rivadavia
# Processing Record 39 of Set 2 | middelburg
# Processing Record 40 of Set 2 | chuy
# Processing Record 41 of Set 2 | pangoa
# Processing Record 42 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 2 | kruisfontein
# Processing Record 44 of Set 2 | vestmannaeyjar
# Processing Record 45 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 2 | rojhan
# Processing Record 47 of Set 2 | arraial do cabo
# Processing Record 48 of Set 2 | misratah
# Processing Record 49 of Set 2 | jega
# Processing Record 50 of Set 2 | bluff
# Processing Record 1 of Set 3 | zhuhai
# Processing Record 2 of Set 3 | klaksvik
# Processing Record 3 of Set 3 | assare
# Processing Record 4 of Set 3 | russell
# Processing Record 5 of Set 3 | henties bay
# Processing Record 6 of Set 3 | marfino
# Processing Record 7 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 3 | mouzakion
# City not found. Skipping...
# Processing Record 9 of Set 3 | port lincoln
# Processing Record 10 of Set 3 | nouakchott
# Processing Record 11 of Set 3 | najran
# Processing Record 12 of Set 3 | sahuaripa
# Processing Record 13 of Set 3 | cherskiy
# Processing Record 14 of Set 3 | alyangula
# Processing Record 15 of Set 3 | bafq
# Processing Record 16 of Set 3 | tanabe
# Processing Record 17 of Set 3 | thinadhoo
# Processing Record 18 of Set 3 | mar del plata
# Processing Record 19 of Set 3 | northam
# Processing Record 20 of Set 3 | clyde river
# Processing Record 21 of Set 3 | karakendzha
# City not found. Skipping...
# Processing Record 22 of Set 3 | bambous virieux
# Processing Record 23 of Set 3 | chokurdakh
# Processing Record 24 of Set 3 | saskylakh
# Processing Record 25 of Set 3 | grand gaube
# Processing Record 26 of Set 3 | fort wellington
# Processing Record 27 of Set 3 | ancud
# Processing Record 28 of Set 3 | yellowknife
# Processing Record 29 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 30 of Set 3 | hammerfest
# Processing Record 31 of Set 3 | narsaq
# Processing Record 32 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 3 | tecpan
# Processing Record 34 of Set 3 | tuktoyaktuk
# Processing Record 35 of Set 3 | gamba
# Processing Record 36 of Set 3 | tongchuan
# Processing Record 37 of Set 3 | paris
# Processing Record 38 of Set 3 | faanui
# Processing Record 39 of Set 3 | ballina
# Processing Record 40 of Set 3 | shelburne
# Processing Record 41 of Set 3 | mbandaka
# Processing Record 42 of Set 3 | korgen
# Processing Record 43 of Set 3 | puerto ayora
# Processing Record 44 of Set 3 | mankono
# Processing Record 45 of Set 3 | paka
# Processing Record 46 of Set 3 | totness
# Processing Record 47 of Set 3 | berlevag
# Processing Record 48 of Set 3 | limon
# Processing Record 49 of Set 3 | brae
# Processing Record 50 of Set 3 | port hueneme
# Processing Record 1 of Set 4 | kodiak
# Processing Record 2 of Set 4 | birao
# Processing Record 3 of Set 4 | aulla
# Processing Record 4 of Set 4 | rylsk
# Processing Record 5 of Set 4 | thompson
# Processing Record 6 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 4 | upington
# Processing Record 8 of Set 4 | kosa
# Processing Record 9 of Set 4 | pangnirtung
# Processing Record 10 of Set 4 | nimbahera
# Processing Record 11 of Set 4 | zhigansk
# Processing Record 12 of Set 4 | east london
# Processing Record 13 of Set 4 | touros
# Processing Record 14 of Set 4 | haines junction
# Processing Record 15 of Set 4 | upata
# Processing Record 16 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 17 of Set 4 | pucallpa
# Processing Record 18 of Set 4 | kununurra
# Processing Record 19 of Set 4 | paramonga
# Processing Record 20 of Set 4 | araquari
# Processing Record 21 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 22 of Set 4 | port-gentil
# Processing Record 23 of Set 4 | uige
# Processing Record 24 of Set 4 | iqaluit
# Processing Record 25 of Set 4 | vostok
# Processing Record 26 of Set 4 | vicksburg
# Processing Record 27 of Set 4 | chilca
# Processing Record 28 of Set 4 | fort nelson
# Processing Record 29 of Set 4 | banjar
# Processing Record 30 of Set 4 | arman
# Processing Record 31 of Set 4 | saint paul
# Processing Record 32 of Set 4 | hohhot
# Processing Record 33 of Set 4 | turukhansk
# Processing Record 34 of Set 4 | veracruz
# Processing Record 35 of Set 4 | ribeira grande
# Processing Record 36 of Set 4 | saint anthony
# Processing Record 37 of Set 4 | oakley
# Processing Record 38 of Set 4 | khandyga
# Processing Record 39 of Set 4 | port elizabeth
# Processing Record 40 of Set 4 | nurota
# Processing Record 41 of Set 4 | necochea
# Processing Record 42 of Set 4 | quatre cocos
# Processing Record 43 of Set 4 | beba
# Processing Record 44 of Set 4 | venustiano carranza
# Processing Record 45 of Set 4 | iskateley
# Processing Record 46 of Set 4 | pochutla
# Processing Record 47 of Set 4 | kaitangata
# Processing Record 48 of Set 4 | ajdabiya
# Processing Record 49 of Set 4 | itoman
# Processing Record 50 of Set 4 | yulara
# Processing Record 1 of Set 5 | lompoc
# Processing Record 2 of Set 5 | esso
# Processing Record 3 of Set 5 | padang
# Processing Record 4 of Set 5 | tura
# Processing Record 5 of Set 5 | cockburn town
# Processing Record 6 of Set 5 | dir
# Processing Record 7 of Set 5 | guicheng
# City not found. Skipping...
# Processing Record 8 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 5 | juneau
# Processing Record 11 of Set 5 | severo-kurilsk
# Processing Record 12 of Set 5 | tigil
# Processing Record 13 of Set 5 | andilamena
# Processing Record 14 of Set 5 | gat
# Processing Record 15 of Set 5 | borogontsy
# Processing Record 16 of Set 5 | faya
# Processing Record 17 of Set 5 | bengkulu
# Processing Record 18 of Set 5 | zaozerne
# Processing Record 19 of Set 5 | sobolevo
# Processing Record 20 of Set 5 | terrace
# Processing Record 21 of Set 5 | hambantota
# Processing Record 22 of Set 5 | okhotsk
# Processing Record 23 of Set 5 | le port
# Processing Record 24 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 5 | makakilo city
# Processing Record 26 of Set 5 | komsomolskiy
# Processing Record 27 of Set 5 | san cristobal
# Processing Record 28 of Set 5 | davenda
# Processing Record 29 of Set 5 | vao
# Processing Record 30 of Set 5 | belmonte
# Processing Record 31 of Set 5 | boa esperanca
# Processing Record 32 of Set 5 | asayita
# City not found. Skipping...
# Processing Record 33 of Set 5 | korhogo
# Processing Record 34 of Set 5 | husavik
# Processing Record 35 of Set 5 | plavinas
# Processing Record 36 of Set 5 | hirara
# Processing Record 37 of Set 5 | uyuni
# Processing Record 38 of Set 5 | shugurovo
# Processing Record 39 of Set 5 | kiama
# Processing Record 40 of Set 5 | natal
# Processing Record 41 of Set 5 | lunavada
# Processing Record 42 of Set 5 | harper
# Processing Record 43 of Set 5 | sinnamary
# Processing Record 44 of Set 5 | waingapu
# Processing Record 45 of Set 5 | greenwood
# Processing Record 46 of Set 5 | lianran
# Processing Record 47 of Set 5 | la ronge
# Processing Record 48 of Set 5 | torbay
# Processing Record 49 of Set 5 | aklavik
# Processing Record 50 of Set 5 | maxixe
# Processing Record 1 of Set 6 | woodward
# Processing Record 2 of Set 6 | minot
# Processing Record 3 of Set 6 | bathurst
# Processing Record 4 of Set 6 | katsuura
# Processing Record 5 of Set 6 | kokopo
# Processing Record 6 of Set 6 | littleton
# Processing Record 7 of Set 6 | salalah
# Processing Record 8 of Set 6 | chicama
# Processing Record 9 of Set 6 | san roque
# Processing Record 10 of Set 6 | gushikawa
# Processing Record 11 of Set 6 | taltal
# Processing Record 12 of Set 6 | utica
# Processing Record 13 of Set 6 | matara
# Processing Record 14 of Set 6 | murgab
# Processing Record 15 of Set 6 | kovdor
# Processing Record 16 of Set 6 | victoria
# Processing Record 17 of Set 6 | la rioja
# Processing Record 18 of Set 6 | umm kaddadah
# Processing Record 19 of Set 6 | phuket
# Processing Record 20 of Set 6 | ponta do sol
# Processing Record 21 of Set 6 | ambanja
# Processing Record 22 of Set 6 | sitka
# Processing Record 23 of Set 6 | nkan
# Processing Record 24 of Set 6 | dinan
# Processing Record 25 of Set 6 | hualmay
# Processing Record 26 of Set 6 | matay
# Processing Record 27 of Set 6 | nome
# Processing Record 28 of Set 6 | tazovskiy
# Processing Record 29 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 30 of Set 6 | qasigiannguit
# Processing Record 31 of Set 6 | ucluelet
# Processing Record 32 of Set 6 | dalinghe
# City not found. Skipping...
# Processing Record 33 of Set 6 | vila franca do campo
# Processing Record 34 of Set 6 | puerto baquerizo moreno
# Processing Record 35 of Set 6 | ratnagiri
# Processing Record 36 of Set 6 | keti bandar
# Processing Record 37 of Set 6 | huarmey
# Processing Record 38 of Set 6 | buala
# Processing Record 39 of Set 6 | carberry
# Processing Record 40 of Set 6 | leningradskiy
# Processing Record 41 of Set 6 | aasmae
# City not found. Skipping...
# Processing Record 42 of Set 6 | nabire
# Processing Record 43 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 44 of Set 6 | porto empedocle
# Processing Record 45 of Set 6 | sangin
# Processing Record 46 of Set 6 | vila velha
# Processing Record 47 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 6 | kamenka
# Processing Record 49 of Set 6 | tacuarembo
# Processing Record 50 of Set 6 | nizwa
# Processing Record 1 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 7 | te anau
# Processing Record 3 of Set 7 | bojnurd
# Processing Record 4 of Set 7 | lokoja
# Processing Record 5 of Set 7 | morro bay
# Processing Record 6 of Set 7 | anadyr
# Processing Record 7 of Set 7 | mount isa
# Processing Record 8 of Set 7 | hinton
# Processing Record 9 of Set 7 | manacapuru
# Processing Record 10 of Set 7 | arvika
# Processing Record 11 of Set 7 | itarema
# Processing Record 12 of Set 7 | caravelas
# Processing Record 13 of Set 7 | mahina
# Processing Record 14 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 7 | los llanos de aridane
# Processing Record 16 of Set 7 | yorosso
# Processing Record 17 of Set 7 | nara
# Processing Record 18 of Set 7 | anloga
# Processing Record 19 of Set 7 | jinchang
# Processing Record 20 of Set 7 | kosikha
# Processing Record 21 of Set 7 | souillac
# Processing Record 22 of Set 7 | tasiilaq
# Processing Record 23 of Set 7 | beira
# Processing Record 24 of Set 7 | axim
# Processing Record 25 of Set 7 | mmabatho
# Processing Record 26 of Set 7 | alofi
# Processing Record 27 of Set 7 | xai-xai
# Processing Record 28 of Set 7 | singaraja
# Processing Record 29 of Set 7 | alpena
# Processing Record 30 of Set 7 | torres
# Processing Record 31 of Set 7 | tual
# Processing Record 32 of Set 7 | capoterra
# Processing Record 33 of Set 7 | calvinia
# Processing Record 34 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 7 | cayenne
# Processing Record 36 of Set 7 | utete
# Processing Record 37 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 7 | san quintin
# Processing Record 39 of Set 7 | nizhniy tsasuchey
# Processing Record 40 of Set 7 | ndola
# Processing Record 41 of Set 7 | caiaponia
# Processing Record 42 of Set 7 | port hedland
# Processing Record 43 of Set 7 | san patricio
# Processing Record 44 of Set 7 | peniche
# Processing Record 45 of Set 7 | valle de san juan
# Processing Record 46 of Set 7 | japura
# Processing Record 47 of Set 7 | maun
# Processing Record 48 of Set 7 | grenfell
# Processing Record 49 of Set 7 | adrar
# Processing Record 50 of Set 7 | tarko-sale
# Processing Record 1 of Set 8 | hervey bay
# Processing Record 2 of Set 8 | atar
# Processing Record 3 of Set 8 | insar
# Processing Record 4 of Set 8 | baoying
# Processing Record 5 of Set 8 | churapcha
# Processing Record 6 of Set 8 | ixtapa
# Processing Record 7 of Set 8 | wenatchee
# Processing Record 8 of Set 8 | chapais
# Processing Record 9 of Set 8 | porto velho
# Processing Record 10 of Set 8 | kologriv
# Processing Record 11 of Set 8 | samana
# Processing Record 12 of Set 8 | ukwa
# Processing Record 13 of Set 8 | griffith
# Processing Record 14 of Set 8 | escanaba
# Processing Record 15 of Set 8 | ketchikan
# Processing Record 16 of Set 8 | esmeraldas
# Processing Record 17 of Set 8 | bukama
# Processing Record 18 of Set 8 | okato
# Processing Record 19 of Set 8 | great yarmouth
# Processing Record 20 of Set 8 | acolla
# Processing Record 21 of Set 8 | bentong
# Processing Record 22 of Set 8 | prince rupert
# Processing Record 23 of Set 8 | dryden
# Processing Record 24 of Set 8 | sao felix do xingu
# Processing Record 25 of Set 8 | egvekinot
# Processing Record 26 of Set 8 | great falls
# Processing Record 27 of Set 8 | baghdad
# Processing Record 28 of Set 8 | dingle
# Processing Record 29 of Set 8 | saint-louis
# Processing Record 30 of Set 8 | ostrovnoy
# Processing Record 31 of Set 8 | otane
# Processing Record 32 of Set 8 | alta floresta
# Processing Record 33 of Set 8 | pevek
# Processing Record 34 of Set 8 | lavras
# Processing Record 35 of Set 8 | valday
# Processing Record 36 of Set 8 | klyuchi
# Processing Record 37 of Set 8 | mandera
# Processing Record 38 of Set 8 | vardo
# Processing Record 39 of Set 8 | dom pedrito
# Processing Record 40 of Set 8 | paragominas
# Processing Record 41 of Set 8 | yar-sale
# Processing Record 42 of Set 8 | avera
# Processing Record 43 of Set 8 | lodja
# Processing Record 44 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 45 of Set 8 | ilebo
# Processing Record 46 of Set 8 | volksrust
# Processing Record 47 of Set 8 | phangnga
# Processing Record 48 of Set 8 | savonlinna
# Processing Record 49 of Set 8 | ewo
# Processing Record 50 of Set 8 | vorotynets
# Processing Record 1 of Set 9 | kutum
# Processing Record 2 of Set 9 | tongzi
# Processing Record 3 of Set 9 | matagami
# Processing Record 4 of Set 9 | olinda
# Processing Record 5 of Set 9 | luderitz
# Processing Record 6 of Set 9 | kwinana
# Processing Record 7 of Set 9 | zhangye
# Processing Record 8 of Set 9 | fallon
# Processing Record 9 of Set 9 | tignere
# Processing Record 10 of Set 9 | tongren
# Processing Record 11 of Set 9 | palmer
# Processing Record 12 of Set 9 | malinyi
# Processing Record 13 of Set 9 | brigantine
# Processing Record 14 of Set 9 | konongo
# Processing Record 15 of Set 9 | mujiayingzi
# Processing Record 16 of Set 9 | mahajanga
# Processing Record 17 of Set 9 | patrocinio
# Processing Record 18 of Set 9 | chernyshevskiy
# Processing Record 19 of Set 9 | chimbote
# Processing Record 20 of Set 9 | corn island
# Processing Record 21 of Set 9 | ugoofaaru
# Processing Record 22 of Set 9 | rijeka
# Processing Record 23 of Set 9 | ipaba
# Processing Record 24 of Set 9 | hasaki
# Processing Record 25 of Set 9 | saint john
# Processing Record 26 of Set 9 | dalby
# Processing Record 27 of Set 9 | nanortalik
# Processing Record 28 of Set 9 | aqtobe
# Processing Record 29 of Set 9 | pozo colorado
# Processing Record 30 of Set 9 | lebanon
# Processing Record 31 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 9 | honiara
# Processing Record 33 of Set 9 | mackay
# Processing Record 34 of Set 9 | nuuk
# Processing Record 35 of Set 9 | caluquembe
# Processing Record 36 of Set 9 | wazzan
# City not found. Skipping...
# Processing Record 37 of Set 9 | north branch
# Processing Record 38 of Set 9 | del rio
# Processing Record 39 of Set 9 | pijijiapan
# Processing Record 40 of Set 9 | mahaicony
# City not found. Skipping...
# Processing Record 41 of Set 9 | peleduy
# Processing Record 42 of Set 9 | kristinehamn
# Processing Record 43 of Set 9 | muzhi
# Processing Record 44 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 9 | englehart
# Processing Record 46 of Set 9 | cascais
# Processing Record 47 of Set 9 | biak
# Processing Record 48 of Set 9 | edgewater
# Processing Record 49 of Set 9 | ca mau
# Processing Record 50 of Set 9 | gidam
# Processing Record 1 of Set 10 | savona
# Processing Record 2 of Set 10 | puerto penasco
# Processing Record 3 of Set 10 | mlonggo
# Processing Record 4 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 10 | duldurga
# Processing Record 6 of Set 10 | qaqortoq
# Processing Record 7 of Set 10 | batagay
# Processing Record 8 of Set 10 | zhigalovo
# Processing Record 9 of Set 10 | guekedou
# City not found. Skipping...
# Processing Record 10 of Set 10 | elizabethton
# Processing Record 11 of Set 10 | tyukhtet
# Processing Record 12 of Set 10 | zdvinsk
# Processing Record 13 of Set 10 | savannah bight
# Processing Record 14 of Set 10 | mittagong
# Processing Record 15 of Set 10 | magistralnyy
# Processing Record 16 of Set 10 | abonnema
# Processing Record 17 of Set 10 | isangel
# Processing Record 18 of Set 10 | filadelfia
# Processing Record 19 of Set 10 | nigde
# Processing Record 20 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 21 of Set 10 | khasan
# Processing Record 22 of Set 10 | vitim
# Processing Record 23 of Set 10 | lubao
# Processing Record 24 of Set 10 | mazulskiy
# City not found. Skipping...
# Processing Record 25 of Set 10 | coruripe
# Processing Record 26 of Set 10 | viedma
# Processing Record 27 of Set 10 | guerrero
# Processing Record 28 of Set 10 | ossora
# Processing Record 29 of Set 10 | merritt island
# Processing Record 30 of Set 10 | toora-khem
# Processing Record 31 of Set 10 | srednekolymsk
# Processing Record 32 of Set 10 | cristinapolis
# Processing Record 33 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 34 of Set 10 | bilibino
# Processing Record 35 of Set 10 | portmore
# Processing Record 36 of Set 10 | korla
# Processing Record 37 of Set 10 | kushima
# Processing Record 38 of Set 10 | chara
# Processing Record 39 of Set 10 | kirakira
# Processing Record 40 of Set 10 | saint-pierre
# Processing Record 41 of Set 10 | havre-saint-pierre
# Processing Record 42 of Set 10 | montrose
# Processing Record 43 of Set 10 | cidreira
# Processing Record 44 of Set 10 | koumac
# Processing Record 45 of Set 10 | aksarka
# Processing Record 46 of Set 10 | okha
# Processing Record 47 of Set 10 | jatiroto
# Processing Record 48 of Set 10 | codrington
# Processing Record 49 of Set 10 | leh
# Processing Record 50 of Set 10 | terney
# Processing Record 1 of Set 11 | bogashevo
# Processing Record 2 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 3 of Set 11 | galveston
# Processing Record 4 of Set 11 | kyren
# Processing Record 5 of Set 11 | kargala
# Processing Record 6 of Set 11 | mitsamiouli
# Processing Record 7 of Set 11 | fortuna
# Processing Record 8 of Set 11 | gweta
# Processing Record 9 of Set 11 | esperance
# Processing Record 10 of Set 11 | ahipara
# Processing Record 11 of Set 11 | omsukchan
# Processing Record 12 of Set 11 | rewari
# Processing Record 13 of Set 11 | kang
# Processing Record 14 of Set 11 | machilipatnam
# Processing Record 15 of Set 11 | soyo
# Processing Record 16 of Set 11 | saiki
# Processing Record 17 of Set 11 | silvino lobos
# Processing Record 18 of Set 11 | norman wells
# Processing Record 19 of Set 11 | abu dhabi
# Processing Record 20 of Set 11 | ulladulla
# Processing Record 21 of Set 11 | guerrero negro
# Processing Record 22 of Set 11 | grindavik
# Processing Record 23 of Set 11 | seda
# Processing Record 24 of Set 11 | san juan
# Processing Record 25 of Set 11 | feni
# Processing Record 26 of Set 11 | talcahuano
# Processing Record 27 of Set 11 | ullapool
# Processing Record 28 of Set 11 | qandala
# Processing Record 29 of Set 11 | pingliang
# Processing Record 30 of Set 11 | zarubino
# Processing Record 31 of Set 11 | sakakah
# Processing Record 32 of Set 11 | espanola
# Processing Record 33 of Set 11 | bismarck
# Processing Record 34 of Set 11 | falkoping
# City not found. Skipping...
# Processing Record 35 of Set 11 | ulaangom
# Processing Record 36 of Set 11 | tiarei
# Processing Record 37 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 38 of Set 11 | mandiana
# Processing Record 39 of Set 11 | coahuayana
# Processing Record 40 of Set 11 | college
# Processing Record 41 of Set 11 | krasnoselkup
# Processing Record 42 of Set 11 | aosta
# Processing Record 43 of Set 11 | yerbogachen
# Processing Record 44 of Set 11 | mahebourg
# Processing Record 45 of Set 11 | novikovo
# Processing Record 46 of Set 11 | uk
# City not found. Skipping...
# Processing Record 47 of Set 11 | fort-shevchenko
# Processing Record 48 of Set 11 | the valley
# Processing Record 49 of Set 11 | almenevo
# City not found. Skipping...
# Processing Record 50 of Set 11 | mwene-ditu
# Processing Record 1 of Set 12 | lorengau
# Processing Record 2 of Set 12 | rio branco
# Processing Record 3 of Set 12 | kirby
# Processing Record 4 of Set 12 | coos bay
# Processing Record 5 of Set 12 | atambua
# Processing Record 6 of Set 12 | emet
# Processing Record 7 of Set 12 | praya
# Processing Record 8 of Set 12 | socha
# Processing Record 9 of Set 12 | portland
# Processing Record 10 of Set 12 | capaccio
# Processing Record 11 of Set 12 | fairbanks
# Processing Record 12 of Set 12 | ust-tsilma
# Processing Record 13 of Set 12 | wahiawa
# Processing Record 14 of Set 12 | picui
# Processing Record 15 of Set 12 | stolin
# Processing Record 16 of Set 12 | luanda
# Processing Record 17 of Set 12 | iranshahr
# Processing Record 18 of Set 12 | dodoma
# Processing Record 19 of Set 12 | flin flon
# Processing Record 20 of Set 12 | abidjan
# Processing Record 21 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 12 | sonoita
# Processing Record 23 of Set 12 | karakose
# City not found. Skipping...
# Processing Record 24 of Set 12 | coquimbo
# Processing Record 25 of Set 12 | yeppoon
# Processing Record 26 of Set 12 | bafra
# Processing Record 27 of Set 12 | bo
# City not found. Skipping...
# Processing Record 28 of Set 12 | pavilosta
# Processing Record 29 of Set 12 | geraldton
# Processing Record 30 of Set 12 | san rafael del sur
# Processing Record 31 of Set 12 | opuwo
# Processing Record 32 of Set 12 | kushmurun
# Processing Record 33 of Set 12 | shingu
# Processing Record 34 of Set 12 | rivarolo canavese
# Processing Record 35 of Set 12 | amapa
# Processing Record 36 of Set 12 | sfantu gheorghe
# Processing Record 37 of Set 12 | lata
# Processing Record 38 of Set 12 | wa
# City not found. Skipping...
# Processing Record 39 of Set 12 | taveta
# Processing Record 40 of Set 12 | deqing
# Processing Record 41 of Set 12 | gorontalo
# Processing Record 42 of Set 12 | banda aceh
# Processing Record 43 of Set 12 | caruray
# Processing Record 44 of Set 12 | amuntai
# Processing Record 45 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 12 | inirida
# Processing Record 47 of Set 12 | bontang
# Processing Record 48 of Set 12 | lavumisa
# Processing Record 49 of Set 12 | ciudad guayana
# Processing Record 50 of Set 12 | grand-lahou
# Processing Record 1 of Set 13 | barreirinha
# Processing Record 2 of Set 13 | waddan
# Processing Record 3 of Set 13 | hofn
# Processing Record 4 of Set 13 | lethem
# Processing Record 5 of Set 13 | gulshat
# City not found. Skipping...
# Processing Record 6 of Set 13 | asau
# Processing Record 7 of Set 13 | killarney
# Processing Record 8 of Set 13 | sabang
# Processing Record 9 of Set 13 | ngorongoro
# Processing Record 10 of Set 13 | halifax
# Processing Record 11 of Set 13 | xuddur
# Processing Record 12 of Set 13 | itacoatiara
# Processing Record 13 of Set 13 | santarem
# Processing Record 14 of Set 13 | jiwani
# Processing Record 15 of Set 13 | carauari
# Processing Record 16 of Set 13 | hope
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 567

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Tiznit  29.5833   -9.5000     65.46        42           0
# 1          Hermanus -34.4187   19.2345     61.00        84          12
# 2       New Norfolk -42.7826  147.0587     55.99        61          99
# 3           Rikitea -23.1203 -134.9692     79.34        75          39
# 4  Krasnorechenskiy  44.6265  135.3532     -9.60        85          11
# 5    Cabo San Lucas  22.8909 -109.9124     77.00        48          85
# 6           Kahului  20.8947 -156.4700     78.80        65          40
# 7        Long Xuyen  10.3833  105.4167     73.40       100          40
# 8         Busselton -33.6500  115.3333     48.99        90           0
# 9         Tuatapere -46.1333  167.6833     50.00        90         100
#
#    Wind Speed Country Current Description                 Date
# 0        1.28      MA           clear sky  2021-01-27 20:39:51
# 1        8.21      ZA          few clouds  2021-01-27 20:33:11
# 2        1.57      AU     overcast clouds  2021-01-27 20:33:25
# 3       14.18      PF    scattered clouds  2021-01-27 20:33:11
# 4        3.91      RU          few clouds  2021-01-27 20:39:52
# 5        4.00      MX     overcast clouds  2021-01-27 20:33:37
# 6       25.32      US    scattered clouds  2021-01-27 20:33:15
# 7        2.30      VN    scattered clouds  2021-01-27 20:35:20
# 8        9.42      AU           clear sky  2021-01-27 20:33:11
# 9       15.01      NZ          light rain  2021-01-27 20:33:20

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Tiznit      MA  29.5833   -9.5000     65.46        42
# 1          Hermanus      ZA -34.4187   19.2345     61.00        84
# 2       New Norfolk      AU -42.7826  147.0587     55.99        61
# 3           Rikitea      PF -23.1203 -134.9692     79.34        75
# 4  Krasnorechenskiy      RU  44.6265  135.3532     -9.60        85
# 5    Cabo San Lucas      MX  22.8909 -109.9124     77.00        48
# 6           Kahului      US  20.8947 -156.4700     78.80        65
# 7        Long Xuyen      VN  10.3833  105.4167     73.40       100
# 8         Busselton      AU -33.6500  115.3333     48.99        90
# 9         Tuatapere      NZ -46.1333  167.6833     50.00        90
#
#    Cloudiness  Wind Speed Current Description
# 0           0        1.28           clear sky
# 1          12        8.21          few clouds
# 2          99        1.57     overcast clouds
# 3          39       14.18    scattered clouds
# 4          11        3.91          few clouds
# 5          85        4.00     overcast clouds
# 6          40       25.32    scattered clouds
# 7          40        2.30    scattered clouds
# 8           0        9.42           clear sky
# 9         100       15.01          light rain

# %%
# Create the output file (CSV).
output_data_file = "weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
